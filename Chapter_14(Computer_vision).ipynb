# %% [markdown]
# CNN(Convolutional neural network)

# %% [markdown]
# The Architecture of the Visual Cortex

# %% [markdown]
# Convolutional Layer

# %% [markdown]
# TensorFlow Implementation -> supposed to complete it by 5 may
