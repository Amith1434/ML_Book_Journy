# %%
import tensorflow as tf

# %% [markdown]
# Data API

# %%
X = tf.range(10)
dataset = tf.data.Dataset.from_tensor_slices(X)
dataset
# Out:
# <_TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>

# %%
for item in dataset:
    print(item)
# Out:
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(3, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# tf.Tensor(6, shape=(), dtype=int32)
# tf.Tensor(7, shape=(), dtype=int32)
# tf.Tensor(8, shape=(), dtype=int32)
# tf.Tensor(9, shape=(), dtype=int32)

# %% [markdown]
# Chaining Transformations

# %%
dataset = dataset.repeat(3).batch(7)
for item in dataset:
    print(item)
# Out:
# tf.Tensor([0 1 2 3 4 5 6], shape=(7,), dtype=int32)
# tf.Tensor([7 8 9 0 1 2 3], shape=(7,), dtype=int32)
# tf.Tensor([4 5 6 7 8 9 0], shape=(7,), dtype=int32)
# tf.Tensor([1 2 3 4 5 6 7], shape=(7,), dtype=int32)
# tf.Tensor([8 9], shape=(2,), dtype=int32)

# %%
dataset
# Out:
# <_BatchDataset element_spec=TensorSpec(shape=(None,), dtype=tf.int32, name=None)>

# %%
dataset = dataset.map(lambda x: x*2)

# %%
dataset = dataset.apply(tf.data.experimental.unbatch())
# Out:
# WARNING:tensorflow:From C:\Users\91911\AppData\Local\Temp\ipykernel_15172\643490874.py:1: unbatch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.unbatch()`.

# %% [markdown]
# Shuffling the Data

# %%
dataset = tf.data.Dataset.range(10).repeat(3)
dataset = dataset.shuffle(buffer_size=5, seed=42).batch(7)
for item in dataset:
    print(item)
# Out:
# tf.Tensor([0 2 3 6 7 9 4], shape=(7,), dtype=int64)
# tf.Tensor([5 0 1 1 8 6 5], shape=(7,), dtype=int64)
# tf.Tensor([4 8 7 1 2 3 0], shape=(7,), dtype=int64)
# tf.Tensor([5 4 2 7 8 9 9], shape=(7,), dtype=int64)
# tf.Tensor([3 6], shape=(2,), dtype=int64)

# %% [markdown]
# Interleaving Lines From Multiple Files

# %% [markdown]
# filepath_dataset = tf.data.Dataset.list_files(train_filepaths, seed = 42)

# %% [markdown]
# can call the interleave() method to read from 5 files at a time and interleave their lines (skipping the first line of each file, which is the header row, using the
# skip() method)

# %% [markdown]
# n_readers = 5<br>
# dataset = filepath_dataset.interleave( lambda filepath: tf.data.TextLineDataset(filepath).skip(1), cycle_length = n_readers)

# %% [markdown]
# Preprocessing the Data

# %% [markdown]
# Prefetching

# %% [markdown]
# while our training algorithm is working
# on one batch, the dataset will already be working in parallel on getting the next batch
# ready. This can improve performance dramatically

# %% [markdown]
# <big>Using the Dataset with tf.keras

# %% [markdown]
# <big>TFRecord

# %%
with tf.io.TFRecordWriter("my_data.tfrecord") as f:
    f.write(b"This is the first record")
    f.write(b"And this is the second record")

# %% [markdown]
# b is to convert it to byte string

# %%
filepaths = ['my_data.tfrecord']
dataset = tf.data.TFRecordDataset(filepaths)
for item in dataset:
    print(item)
# Out:
# tf.Tensor(b'This is the first record', shape=(), dtype=string)
# tf.Tensor(b'And this is the second record', shape=(), dtype=string)

# %% [markdown]
# Compressed TFRecord Files

# %% [markdown]
# options = tf.io.TFRecordOptions(compression_type = "GZIP")<br>
# with tf.io.TFRcordWrter("my_compressed.tfrecord", options) as f: <br>
# ......................

# %% [markdown]
# <big>Protocol Buffers

# %% [markdown]
# Skipping this chapter for now
