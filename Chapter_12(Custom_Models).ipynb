# %% [markdown]
# Operations with Tensor

# %%
import tensorflow as tf

# %%
t = tf.constant([[1,2,3],[4,5,6]]) #vector

# %%
tf.constant(42) #Scaler
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=42>

# %%
t @ tf.transpose(t)        #Or use tf.matmul()
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[14, 32],
#        [32, 77]], dtype=int32)>

# %%
tf.squeeze(t)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)>

# %%
t
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)>

# %%
t = tf.constant([[[1, 2, 3]]])  
print(t.shape)  # (1, 1, 3)

print(tf.squeeze(t))
# Out:
# (1, 1, 3)
# tf.Tensor([1 2 3], shape=(3,), dtype=int32)

# %%
t = tf.constant([[[1, 2, 3]]])

t_squeezed = tf.squeeze(t)

print(t.shape)           # (1, 1, 3)
print(t_squeezed.shape)  # (3,)
# Out:
# (1, 1, 3)
# (3,)

# %% [markdown]
# Tensors and Numpy

# %%
import numpy as np
a = np.array([2,4,5])
t = tf.constant(a)

# %%
t.numpy()
# Out:
# array([2, 4, 5])

# %% [markdown]
# Type Conversion

# %%
tf.constant(2.) + tf.constant(42.)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=44.0>

# %%
t2 = tf.constant(40, dtype=tf.float64)
tf.constant(2.0) + tf.cast(t2,tf.float32)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=42.0>

# %% [markdown]
# Variables

# %%
v= tf.Variable([[1,2,3],[4,5,6]])
v
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)>

# %%
v.assign(2*v)
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 3) dtype=int32, numpy=
# array([[ 2,  4,  6],
#        [ 8, 10, 12]], dtype=int32)>

# %%
v[0,1].assign(40)
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 3) dtype=int32, numpy=
# array([[ 2, 40,  6],
#        [ 8, 10, 12]], dtype=int32)>

# %% [markdown]
# <big>Customizing Models and Training Algorithms

# %% [markdown]
# Custom Loss Function

# %% [markdown]
# Huber Loss

# %%
def create_huber(threshold=1.0):
 def huber_fn(y_true, y_pred):
    error = y_true - y_pred
    is_small_error = tf.abs(error) < threshold
    squared_loss = tf.square(error) / 2
    linear_loss = threshold * tf.abs(error) - threshold**2 / 2
    return tf.where(is_small_error, squared_loss, linear_loss)
    return huber_fn

# %% [markdown]
# saving and Loading Models that contains Custom Components

# %% [markdown]
# model = keras.models.load_model("my_custom_model.h5",custom_objects={"huber_fn":create_huber(2.0)})

# %% [markdown]
# Custom Activation Function, Initializers, Regularizers and Constraints

# %% [markdown]
# Custom Metrics

# %% [markdown]
# Just reading these parts

# %% [markdown]
# I don't think I need to write custom functions for now, so I will look at this part in future
